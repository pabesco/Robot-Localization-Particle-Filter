# %% [markdown]
# Robot Localization with Python and Particle Filters
# ===================================================

# %% [markdown]
# Import libraries and load map.

# %%
import numpy as np
import cv2

map = cv2.imread("map.png", 0)
print(map)
HEIGHT, WIDTH = map.shape

rx, ry, rtheta = (WIDTH/4, HEIGHT/4, 0)
# Out:
# [[ 79  80  82 ... 133 148 156]
#  [ 78  79  81 ... 138 156 164]
#  [ 76  77  79 ... 147 170 180]
#  ...
#  [181 181 182 ... 174 172 171]
#  [178 178 178 ... 180 179 178]
#  [177 177 177 ... 183 182 182]]

# %% [markdown]
# Map coordinate system
#
# ![title](images/coords.png)
#
# CAUTION: The terrain height at X,Y coordinates is map(Y,X).

# %% [markdown]
# Read keyboard input.

# %%
STEP = 5
TURN=  np.radians(25)
def get_input():
    fwd = 0
    turn = 0
    halt = False
    k = cv2.waitKey(0)
    print(k)
    if k == 56:
        fwd = STEP
    elif k == 54:
        turn = TURN
    elif k == 52:
        turn = -TURN
    else:
        halt = True
    return fwd, turn, halt

# %% [markdown]
# Move the robot, with Gausssian noise.
#
# ![title](images/gaussian.png)

# %%
SIGMA_STEP = 0.5 #pixels
SIGMA_TURN = np.radians(5)

def move_robot(rx, ry, rtheta, fwd, turn):
    fwd_noisy = np.random.normal(fwd, SIGMA_STEP, 1)
    print("fwd_noisy = ", fwd_noisy)
    
    rx += fwd_noisy * np.cos(rtheta)
    ry += fwd_noisy * np.sin(rtheta)
    
    turn_noisy = np.random.normal(turn, SIGMA_TURN, 1)
    print("turn_noisy = ", np.degrees(turn_noisy))
    
    rtheta += turn_noisy

    return rx, ry, rtheta

# %% [markdown]
# Initialize particle cloud.

# %%
NUM_PARTICLES = 3000

def init():
    particles = np.random.rand(NUM_PARTICLES, 3) #3000 particles with three attributes rx, ry and rtheta
    particles *= np.array( (WIDTH, HEIGHT, np.radians(360)))
    return particles

# %% [markdown]
# Move the particles.

# %%
def move_particles(particles, fwd, turn):
    particles[:, 0] += fwd * np.cos(particles[:,2])
    particles[:, 1] += fwd * np.sin(particles[:,2])
    particles[:, 2] += turn
    
    particles[:,0] = np.clip(particles[:,0], 0.0, WIDTH-1)
    particles[:,1] = np.clip(particles[:,1], 0.0, HEIGHT-1)
    return particles

# %% [markdown]
# Get value from robot's sensor.

# %%
SIGMA_SENSOR = 2
def sense(x, y, noisy=False):
    x = int(x)
    y = int(y)
    if noisy:
        return np.random.normal(map[y, x], SIGMA_SENSOR, 1)
    return map[y, x]

# %% [markdown]
# Compute particle weights.

# %%
def compute_weights(particles, robot_sensor):    
    errors = np.zeros(NUM_PARTICLES)
    for i in range(NUM_PARTICLES):
        elevation = sense(particles[i, 0], particles[i, 1], noisy=False)
        errors[i] = abs(robot_sensor - elevation)
        
    weights = np.max(errors) - errors
    
    weights[
        (particles[:, 0] == 0) |
        (particles[:,0] == WIDTH-1) |
        (particles[:,1] == 0) |
        (particles[:,1] == HEIGHT-1)
    ] = 0.0
    
    weights = weights ** 3
    return weights

# %% [markdown]
# Resample the particles.

# %%
def resample(particles, weights):
    probabilities = weights/np.sum(weights)
    
    new_index = np.random.choice(
        NUM_PARTICLES,
        size = NUM_PARTICLES,
        p = probabilities)
    
    particles = particles[new_index, :]
     
    return particles

# %% [markdown]
# Add noise to the particles.

# %%
SIGMA_POS = 2
SIGMA_TURN = np.radians(10)

def add_noise(particles):
    noise  = np.concatenate(
        (
            np.random.normal(0, SIGMA_POS, (NUM_PARTICLES, 1)),
            np.random.normal(0, SIGMA_POS, (NUM_PARTICLES, 1)),
            np.random.normal(0, SIGMA_TURN, (NUM_PARTICLES, 1))
        ), 
        axis=1
    )
    particles += noise
    return particles

# %% [markdown]
# Display robot, particles and best guess.

# %%
def display(map, rx, ry, particles):
    lmap = cv2.cvtColor(map, cv2.COLOR_GRAY2BGR)
    
    # Display particles
    if len(particles) > 0:
        for i in range(NUM_PARTICLES):
            cv2.circle(lmap, 
                       (int(particles[i,0]), int(particles[i,1])), 
                       1, 
                       (255,0,0), 
                       1)
        
    # Display robot
    cv2.circle(lmap, (int(rx), int(ry)), 5, (0,255,0), 10)

    # Display best guess
    if len(particles) > 0:
        px = np.mean(particles[:,0])
        py = np.mean(particles[:,1])
        cv2.circle(lmap, (int(px), int(py)), 5, (0,0,255), 5)

    cv2.imshow('map', lmap)

# %% [markdown]
# Main routine.

# %%
particles = init()
while True:
    display(map, rx, ry, particles)
    fwd, turn, halt = get_input()
    if halt:
        break
    rx, ry, rtheta = move_robot(rx, ry, rtheta, fwd, turn)
    particles = move_particles(particles, fwd, turn)
    if fwd != 0:
        robot_sensor = sense(rx, ry, noisy=True)        
        weights = compute_weights(particles, robot_sensor)
        particles = resample(particles, weights)
        particles = add_noise(particles)
    cv2.destroyAllWindows()                        

cv2.destroyAllWindows()
# Out:
# 56
# fwd_noisy =  [4.2688326]
# turn_noisy =  [-4.10421229]
# 56
# fwd_noisy =  [4.59537533]
# turn_noisy =  [-6.02328109]
# 54
# fwd_noisy =  [-0.6825363]
# turn_noisy =  [32.98204465]
# 56
# fwd_noisy =  [5.37425834]
# turn_noisy =  [-17.12754428]
# 56
# fwd_noisy =  [5.85253304]
# turn_noisy =  [-5.20857138]
# 52
# fwd_noisy =  [0.1930701]
# turn_noisy =  [-24.59695729]
# 56
# fwd_noisy =  [4.54994713]
# turn_noisy =  [5.30424001]
# 56
# fwd_noisy =  [4.82378856]
# turn_noisy =  [10.11350175]
# 56
# fwd_noisy =  [4.91326639]
# turn_noisy =  [-8.49930604]
# 52
# fwd_noisy =  [-0.38106633]
# turn_noisy =  [-8.42536451]
# 56
# fwd_noisy =  [4.46894252]
# turn_noisy =  [5.68176454]
# 56
# fwd_noisy =  [4.90256997]
# turn_noisy =  [-9.34060703]
# 56
# fwd_noisy =  [4.60830931]
# turn_noisy =  [23.42068741]
# 56
# fwd_noisy =  [4.92160932]
# turn_noisy =  [9.71181692]
# 56
# fwd_noisy =  [4.79201217]
# turn_noisy =  [-8.40665728]
# 54
# fwd_noisy =  [-0.69510734]
# turn_noisy =  [32.47772844]
# 54
# fwd_noisy =  [0.54101781]
# turn_noisy =  [35.20013168]
# 56
# fwd_noisy =  [5.61644974]
# turn_noisy =  [10.58655725]
# 56
# fwd_noisy =  [4.92916497]
# turn_noisy =  [1.37690853]
# 56
# fwd_noisy =  [5.27123038]
# turn_noisy =  [8.43570069]
# 56
# fwd_noisy =  [4.23576968]
# turn_noisy =  [-7.66644492]
# 56
# fwd_noisy =  [5.46651962]
# turn_noisy =  [1.52510375]
# 56
# fwd_noisy =  [5.04834779]
# turn_noisy =  [3.14661376]
# 54
# fwd_noisy =  [0.14446612]
# turn_noisy =  [5.41656761]
# 56
# fwd_noisy =  [4.51633113]
# turn_noisy =  [-10.703988]
# 54
# fwd_noisy =  [-0.12297609]
# turn_noisy =  [17.88750909]
# 56
# fwd_noisy =  [5.64547824]
# turn_noisy =  [4.53713864]
# 56
# fwd_noisy =  [4.58055903]
# turn_noisy =  [-10.35225724]
# 56
# fwd_noisy =  [5.25840583]
# turn_noisy =  [7.098895]
# 56
# fwd_noisy =  [4.51100005]
# turn_noisy =  [-1.3111047]
# 54
# fwd_noisy =  [-0.10813595]
# turn_noisy =  [19.71998007]
# 56
# fwd_noisy =  [5.24065279]
# turn_noisy =  [-11.71937182]
# 56
# fwd_noisy =  [5.39088191]
# turn_noisy =  [6.12369915]
# 56
# fwd_noisy =  [4.3181437]
# turn_noisy =  [7.31265573]
# 56
# fwd_noisy =  [5.13506052]
# turn_noisy =  [-21.27780577]
# 56
# fwd_noisy =  [4.94574517]
# turn_noisy =  [-28.64354272]
# 56
# fwd_noisy =  [4.92196919]
# turn_noisy =  [0.80137987]
# 56
# fwd_noisy =  [5.22088944]
# turn_noisy =  [-0.40876059]
# 56
# fwd_noisy =  [6.36224617]
# turn_noisy =  [0.14276545]
# 56
# fwd_noisy =  [5.48022305]
# turn_noisy =  [11.89079331]
# 56
# fwd_noisy =  [4.87065335]
# turn_noisy =  [-17.02288612]
# 56
# fwd_noisy =  [5.14840504]
# turn_noisy =  [1.11609957]
# 56
# fwd_noisy =  [5.22081736]
# turn_noisy =  [-15.87636164]
# 56
# fwd_noisy =  [4.8127054]
# turn_noisy =  [0.60008814]
# 56
# fwd_noisy =  [5.13038751]
# turn_noisy =  [7.69132722]
# 54
# fwd_noisy =  [0.35274948]
# turn_noisy =  [27.64843059]
# 56
# fwd_noisy =  [4.92243837]
# turn_noisy =  [-5.18777799]
# 56
# fwd_noisy =  [4.67486116]
# turn_noisy =  [-4.39148355]
# 56
# fwd_noisy =  [4.55900869]
# turn_noisy =  [-0.59151581]
# 56
# fwd_noisy =  [5.39818723]
# turn_noisy =  [1.49639677]
# 56
# fwd_noisy =  [4.39253461]
# turn_noisy =  [12.60311528]
# 56
# fwd_noisy =  [4.11207854]
# turn_noisy =  [-2.98071984]
# 56
# fwd_noisy =  [4.70022109]
# turn_noisy =  [-0.08927305]
# 56
# fwd_noisy =  [5.53144796]
# turn_noisy =  [-7.14926242]
# 56
# fwd_noisy =  [3.98056274]
# turn_noisy =  [-1.61536657]
# 56
# fwd_noisy =  [4.83600898]
# turn_noisy =  [6.5365792]
# 56
# fwd_noisy =  [5.19713264]
# turn_noisy =  [-10.24176018]
# 56
# fwd_noisy =  [5.47501268]
# turn_noisy =  [-14.55893834]
# 56
# fwd_noisy =  [5.97996134]
# turn_noisy =  [2.46180521]
# 56
# fwd_noisy =  [5.38383362]
# turn_noisy =  [1.1323445]
# 56
# fwd_noisy =  [5.5196604]
# turn_noisy =  [-2.82824635]
# 54
# fwd_noisy =  [0.64924898]
# turn_noisy =  [24.7938599]
# 56
# fwd_noisy =  [4.76399126]
# turn_noisy =  [-23.71327615]
# 56
# fwd_noisy =  [5.13031912]
# turn_noisy =  [-3.59190846]
# 56
# fwd_noisy =  [5.54182985]
# turn_noisy =  [-4.84873143]
# 56
# fwd_noisy =  [5.06796745]
# turn_noisy =  [11.78923746]
# 56
# fwd_noisy =  [5.15403997]
# turn_noisy =  [-13.66463943]
# 56
# fwd_noisy =  [5.05744803]
# turn_noisy =  [-1.38432192]
# 56
# fwd_noisy =  [5.20669004]
# turn_noisy =  [15.73351796]
# 54
# fwd_noisy =  [0.46923785]
# turn_noisy =  [31.89381818]
# 56
# fwd_noisy =  [5.97342514]
# turn_noisy =  [-3.66001884]
# 56
# fwd_noisy =  [5.00325043]
# turn_noisy =  [-7.71285162]
# 56
# fwd_noisy =  [5.22812233]
# turn_noisy =  [3.01850992]
# 56
# fwd_noisy =  [4.89600075]
# turn_noisy =  [14.33003578]
# 56
# fwd_noisy =  [4.7731287]
# turn_noisy =  [-6.22705725]
# 56
# fwd_noisy =  [4.90621434]
# turn_noisy =  [-1.09477219]
# 56
# fwd_noisy =  [5.5123891]
# turn_noisy =  [2.05171813]
# 56
# fwd_noisy =  [5.1116007]
# turn_noisy =  [2.89022936]
# 56
# fwd_noisy =  [5.7494859]
# turn_noisy =  [-0.51895822]
# 56
# fwd_noisy =  [4.41362889]
# turn_noisy =  [-16.28389314]
# 54
# fwd_noisy =  [1.51848133]
# turn_noisy =  [23.53055287]
# 56
# fwd_noisy =  [4.69052049]
# turn_noisy =  [-10.71430312]
# 56
# fwd_noisy =  [5.38134818]
# turn_noisy =  [13.94668858]
# 56
# fwd_noisy =  [4.52149939]
# turn_noisy =  [-4.57436983]
# 56
# fwd_noisy =  [4.53514715]
# turn_noisy =  [-8.37881952]
# 56
# fwd_noisy =  [5.12554023]
# turn_noisy =  [12.61391682]
# 56
# fwd_noisy =  [5.20247641]
# turn_noisy =  [4.74756927]
# 56
# fwd_noisy =  [4.91189292]
# turn_noisy =  [1.14524374]
# 56
# fwd_noisy =  [5.94693173]
# turn_noisy =  [-7.70939596]
# 56
# fwd_noisy =  [5.27778312]
# turn_noisy =  [-1.82305576]
# 56
# fwd_noisy =  [5.02234537]
# turn_noisy =  [-10.82928662]
# 56
# fwd_noisy =  [5.07958846]
# turn_noisy =  [-3.19755983]
# 56
# fwd_noisy =  [5.20763466]
# turn_noisy =  [-1.14034168]
# 56
# fwd_noisy =  [4.26102743]
# turn_noisy =  [5.75909061]
# 56
# fwd_noisy =  [6.13465187]
# turn_noisy =  [-8.69268002]
# 56
# fwd_noisy =  [4.42493124]
# turn_noisy =  [13.07085988]
# 56
# fwd_noisy =  [5.71762148]
# turn_noisy =  [7.79307885]
# 56
# fwd_noisy =  [5.51650903]
# turn_noisy =  [4.68536299]
# 56
# fwd_noisy =  [3.97541303]
# turn_noisy =  [-6.53573219]
# 56
# fwd_noisy =  [5.20147182]
# turn_noisy =  [3.21719729]
# 54
# fwd_noisy =  [0.41765269]
# turn_noisy =  [40.74893449]
# 56
# fwd_noisy =  [4.68144254]
# turn_noisy =  [-3.22565928]
# 56
# fwd_noisy =  [4.07874686]
# turn_noisy =  [2.35819392]
# 56
# fwd_noisy =  [5.48121897]
# turn_noisy =  [-5.70620141]
# 56
# fwd_noisy =  [4.94774247]
# turn_noisy =  [-5.89476175]
# 56
# fwd_noisy =  [4.68711304]
# turn_noisy =  [-3.05652874]
# 56
# fwd_noisy =  [4.90888366]
# turn_noisy =  [7.69274525]
# 56
# fwd_noisy =  [4.36791858]
# turn_noisy =  [16.61720328]
# 56
# fwd_noisy =  [4.62268052]
# turn_noisy =  [12.65304026]
# 56
# fwd_noisy =  [5.38277509]
# turn_noisy =  [2.70297088]
# 56
# fwd_noisy =  [5.06065596]
# turn_noisy =  [1.44554144]
# 56
# fwd_noisy =  [5.05153242]
# turn_noisy =  [1.4707572]
# 56
# fwd_noisy =  [4.86647508]
# turn_noisy =  [-2.27179218]
# 54
# fwd_noisy =  [-0.13702263]
# turn_noisy =  [35.82779568]
# 56
# fwd_noisy =  [4.63397574]
# turn_noisy =  [-3.38707994]
# 54
# fwd_noisy =  [-0.51494302]
# turn_noisy =  [12.31615373]
# 54
# fwd_noisy =  [-0.13930026]
# turn_noisy =  [29.05449962]
# 56
# fwd_noisy =  [5.42763932]
# turn_noisy =  [1.90164172]
# 56
# fwd_noisy =  [4.86782728]
# turn_noisy =  [10.06544782]
# 56
# fwd_noisy =  [4.61721464]
# turn_noisy =  [13.27166101]
# 56
# fwd_noisy =  [4.49946265]
# turn_noisy =  [14.63741456]
# 56
# fwd_noisy =  [4.37972292]
# turn_noisy =  [6.30875896]
# 56
# fwd_noisy =  [5.16445794]
# turn_noisy =  [-6.15977728]
# 56
# fwd_noisy =  [4.54393026]
# turn_noisy =  [-7.85368857]
# 56
# fwd_noisy =  [4.41134125]
# turn_noisy =  [-0.19438329]
# 56
# fwd_noisy =  [5.00061856]
# turn_noisy =  [14.36336427]
# 56
# fwd_noisy =  [4.66341153]
# turn_noisy =  [-13.87335449]
# 56
# fwd_noisy =  [5.14456907]
# turn_noisy =  [-5.27456098]
# 56
# fwd_noisy =  [5.67200022]
# turn_noisy =  [1.39799525]
# 56
# fwd_noisy =  [5.43310719]
# turn_noisy =  [11.10548524]
# 56
# fwd_noisy =  [5.0473284]
# turn_noisy =  [19.85095784]
# 56
# fwd_noisy =  [5.31709634]
# turn_noisy =  [5.03008365]
# 56
# fwd_noisy =  [5.03589636]
# turn_noisy =  [6.87970301]
# 56
# fwd_noisy =  [5.63372843]
# turn_noisy =  [-2.45999076]
# 56
# fwd_noisy =  [5.01813024]
# turn_noisy =  [-3.11354039]
# 56
# fwd_noisy =  [5.57024557]
# turn_noisy =  [5.99185767]
# 54
# fwd_noisy =  [0.84704619]
# turn_noisy =  [24.13114805]
# 56
# fwd_noisy =  [5.4704695]
# turn_noisy =  [-2.86573443]
# 56
# fwd_noisy =  [5.36668938]
# turn_noisy =  [11.58563764]
# 56
# fwd_noisy =  [5.55692986]
# turn_noisy =  [16.30985844]
# 56
# fwd_noisy =  [4.91263675]
# turn_noisy =  [-4.41671389]
# 56
# fwd_noisy =  [5.61444378]
# turn_noisy =  [-7.91670542]
# 56
# fwd_noisy =  [5.17011229]
# turn_noisy =  [7.41492942]
# 56
# fwd_noisy =  [5.0327023]
# turn_noisy =  [-5.76236345]
# 56
# fwd_noisy =  [4.49282303]
# turn_noisy =  [-1.73119396]
# 56
# fwd_noisy =  [5.39352181]
# turn_noisy =  [6.9112838]
# 56
# fwd_noisy =  [5.0237907]
# turn_noisy =  [-11.67577913]
# 56
# fwd_noisy =  [5.2350851]
# turn_noisy =  [-9.72926487]
# 56
# fwd_noisy =  [4.80574436]
# turn_noisy =  [-16.18317357]
# 56
# fwd_noisy =  [5.23295397]
# turn_noisy =  [-0.65562204]
# 56
# fwd_noisy =  [5.26131121]
# turn_noisy =  [-0.0238386]
# 56
# fwd_noisy =  [5.39931929]
# turn_noisy =  [14.22203661]
# 52
# fwd_noisy =  [-0.25889195]
# turn_noisy =  [-32.44070039]
# 56
# fwd_noisy =  [4.85844605]
# turn_noisy =  [-3.1333771]
# 56
# fwd_noisy =  [4.47281187]
# turn_noisy =  [9.52387674]
# 56
# fwd_noisy =  [4.19718652]
# turn_noisy =  [1.68616504]
# 56
# fwd_noisy =  [4.4843228]
# turn_noisy =  [3.48994625]
# 52
# fwd_noisy =  [-0.33599221]
# turn_noisy =  [-25.52122346]
# 56
# fwd_noisy =  [4.70807214]
# turn_noisy =  [9.07540221]
# 52
# fwd_noisy =  [-0.47609594]
# turn_noisy =  [-42.58517937]
# 56
# fwd_noisy =  [4.96576062]
# turn_noisy =  [4.92542936]
# 52
# fwd_noisy =  [0.27355384]
# turn_noisy =  [-26.77953221]
# 56
# fwd_noisy =  [5.40862235]
# turn_noisy =  [0.67549153]
# 52
# fwd_noisy =  [0.03549764]
# turn_noisy =  [-36.94356746]
# 56
# fwd_noisy =  [4.21067456]
# turn_noisy =  [-6.20748494]
# 56
# fwd_noisy =  [5.5829045]
# turn_noisy =  [3.48086904]
# 56
# fwd_noisy =  [5.14087647]
# turn_noisy =  [-2.75749021]
# 56
# fwd_noisy =  [4.35141121]
# turn_noisy =  [0.88177547]
# 56
# fwd_noisy =  [5.94742699]
# turn_noisy =  [20.32596141]
# 56
# fwd_noisy =  [5.1266371]
# turn_noisy =  [22.01278391]
# 56
# fwd_noisy =  [5.95912243]
# turn_noisy =  [-5.699819]
# 56
# fwd_noisy =  [5.00670897]
# turn_noisy =  [-4.19339935]
# 56
# fwd_noisy =  [5.39695512]
# turn_noisy =  [17.15035947]
# 52
# fwd_noisy =  [1.11802672]
# turn_noisy =  [-32.9795844]
# 56
# fwd_noisy =  [4.60439571]
# turn_noisy =  [6.93373125]
# 56
# fwd_noisy =  [5.2824834]
# turn_noisy =  [11.91409329]
# 56
# fwd_noisy =  [4.86606587]
# turn_noisy =  [10.30501768]
# 56
# fwd_noisy =  [5.07370385]
# turn_noisy =  [3.27239162]
# 56
# fwd_noisy =  [5.578896]
# turn_noisy =  [15.74957983]
# 56
# fwd_noisy =  [5.37635185]
# turn_noisy =  [-3.87969117]
# 56
# fwd_noisy =  [4.44400701]
# turn_noisy =  [0.17755765]
# 56
# fwd_noisy =  [4.95945101]
# turn_noisy =  [-10.23125122]
# 56
# fwd_noisy =  [4.9712857]
# turn_noisy =  [11.13863918]
# 56
# fwd_noisy =  [4.94935955]
# turn_noisy =  [8.17718891]
# 54
# fwd_noisy =  [-0.32895092]
# turn_noisy =  [26.86404081]
# 56
# fwd_noisy =  [5.20299936]
# turn_noisy =  [-0.62323751]
# 56
# fwd_noisy =  [5.47619904]
# turn_noisy =  [-8.10293935]
# 54
# fwd_noisy =  [-0.31116614]
# turn_noisy =  [32.4176901]
# 56
# fwd_noisy =  [5.05693737]
# turn_noisy =  [3.99416121]
# 52
# fwd_noisy =  [-0.24676214]
# turn_noisy =  [-33.99083158]
# 52
# fwd_noisy =  [-0.53682575]
# turn_noisy =  [-26.81242358]
# 52
# fwd_noisy =  [0.22313768]
# turn_noisy =  [-16.39944736]
# 56
# fwd_noisy =  [5.2495252]
# turn_noisy =  [11.76376609]
# 56
# fwd_noisy =  [4.49555141]
# turn_noisy =  [6.44708819]
# 56
# fwd_noisy =  [5.20324235]
# turn_noisy =  [6.65584442]
# 56
# fwd_noisy =  [4.85594617]
# turn_noisy =  [-4.58591009]
# 52
# fwd_noisy =  [0.46191718]
# turn_noisy =  [-20.90047759]
# 52
# fwd_noisy =  [0.45327752]
# turn_noisy =  [-34.51404454]
# 52
# fwd_noisy =  [1.07136082]
# turn_noisy =  [-49.0874695]
# 52
# fwd_noisy =  [-0.03184993]
# turn_noisy =  [-40.41800116]
# 56
# fwd_noisy =  [3.84762588]
# turn_noisy =  [8.75185799]
# 52
# fwd_noisy =  [0.05953637]
# turn_noisy =  [-5.7261104]
# 56
# fwd_noisy =  [4.2610579]
# turn_noisy =  [-0.98834033]
# 56
# fwd_noisy =  [5.2003693]
# turn_noisy =  [13.80690682]
# 52
# fwd_noisy =  [0.74338069]
# turn_noisy =  [-26.96754552]
# 52
# fwd_noisy =  [-0.16629146]
# turn_noisy =  [-37.56534208]
# 56
# fwd_noisy =  [4.49714153]
# turn_noisy =  [-16.2122759]
# 52
# fwd_noisy =  [0.10399297]
# turn_noisy =  [-16.8137269]
# 52
# fwd_noisy =  [0.39159211]
# turn_noisy =  [-23.47483937]
# 56
# fwd_noisy =  [4.62965404]
# turn_noisy =  [-9.02565517]
# 52
# fwd_noisy =  [-0.37885389]
# turn_noisy =  [-30.93050083]
# 56
# fwd_noisy =  [5.11344053]
# turn_noisy =  [0.73116782]
# 52
# fwd_noisy =  [0.44245927]
# turn_noisy =  [-39.83069654]
# 56
# fwd_noisy =  [4.44346484]
# turn_noisy =  [23.0181965]
# 52
# fwd_noisy =  [-0.33627986]
# turn_noisy =  [-18.52538384]
# 52
# fwd_noisy =  [0.0767232]
# turn_noisy =  [-20.86843835]
# 56
# fwd_noisy =  [5.3939645]
# turn_noisy =  [-4.68060508]
# 56
# fwd_noisy =  [4.91207633]
# turn_noisy =  [3.10292973]
# 55
