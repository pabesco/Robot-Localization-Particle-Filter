# %% [markdown]
# Robot Localization with Python and Particle Filters
# ===================================================

# %% [markdown]
# Import libraries and load map.

# %%
import numpy as np
import cv2
from cv2 import VideoWriter
from cv2 import VideoWriter_fourcc


map = cv2.imread("map.png", 0)
print(map)
HEIGHT, WIDTH = map.shape

video = VideoWriter(f'Robot_Localization.avi', VideoWriter_fourcc(*'MP42'), 15, (WIDTH, HEIGHT))


rx, ry, rtheta = (WIDTH/4, HEIGHT/4, 0)
# Out:
# [[ 79  80  82 ... 133 148 156]
#  [ 78  79  81 ... 138 156 164]
#  [ 76  77  79 ... 147 170 180]
#  ...
#  [181 181 182 ... 174 172 171]
#  [178 178 178 ... 180 179 178]
#  [177 177 177 ... 183 182 182]]

# %% [markdown]
# Map coordinate system
#
# ![title](images/coords.png)
#
# CAUTION: The terrain height at X,Y coordinates is map(Y,X).

# %% [markdown]
# Read keyboard input.

# %%
STEP = 5
TURN=  np.radians(25)
def get_input():
    fwd = 0
    turn = 0
    halt = False
    k = cv2.waitKey(0)
    print(k)
    if k == 56:
        fwd = STEP
    elif k == 54:
        turn = TURN
    elif k == 52:
        turn = -TURN
    else:
        halt = True
    return fwd, turn, halt

# %% [markdown]
# Move the robot, with Gausssian noise.
#
# ![title](images/gaussian.png)

# %%
SIGMA_STEP = 0.5 #pixels
SIGMA_TURN = np.radians(5)

def move_robot(rx, ry, rtheta, fwd, turn):
    fwd_noisy = np.random.normal(fwd, SIGMA_STEP, 1)
    print("fwd_noisy = ", fwd_noisy)
    
    rx += fwd_noisy * np.cos(rtheta)
    ry += fwd_noisy * np.sin(rtheta)
    
    turn_noisy = np.random.normal(turn, SIGMA_TURN, 1)
    print("turn_noisy = ", np.degrees(turn_noisy))
    
    rtheta += turn_noisy

    return rx, ry, rtheta

# %% [markdown]
# Initialize particle cloud.

# %%
NUM_PARTICLES = 3000

def init():
    particles = np.random.rand(NUM_PARTICLES, 3) #3000 particles with three attributes rx, ry and rtheta
    particles *= np.array( (WIDTH, HEIGHT, np.radians(360)))
    return particles

# %% [markdown]
# Move the particles.

# %%
def move_particles(particles, fwd, turn):
    particles[:, 0] += fwd * np.cos(particles[:,2])
    particles[:, 1] += fwd * np.sin(particles[:,2])
    particles[:, 2] += turn
    
    particles[:,0] = np.clip(particles[:,0], 0.0, WIDTH-1)
    particles[:,1] = np.clip(particles[:,1], 0.0, HEIGHT-1)
    return particles

# %% [markdown]
# Get value from robot's sensor.

# %%
SIGMA_SENSOR = 2
def sense(x, y, noisy=False):
    x = int(x)
    y = int(y)
    if noisy:
        return np.random.normal(map[y, x], SIGMA_SENSOR, 1)
    return map[y, x]

# %% [markdown]
# Compute particle weights.

# %%
def compute_weights(particles, robot_sensor):    
    errors = np.zeros(NUM_PARTICLES)
    for i in range(NUM_PARTICLES):
        elevation = sense(particles[i, 0], particles[i, 1], noisy=False)
        errors[i] = abs(robot_sensor - elevation)
        
    weights = np.max(errors) - errors
    
    weights[
        (particles[:, 0] == 0) |
        (particles[:,0] == WIDTH-1) |
        (particles[:,1] == 0) |
        (particles[:,1] == HEIGHT-1)
    ] = 0.0
    
    weights = weights ** 3
    return weights

# %% [markdown]
# Resample the particles.

# %%
def resample(particles, weights):
    probabilities = weights/np.sum(weights)
    
    new_index = np.random.choice(
        NUM_PARTICLES,
        size = NUM_PARTICLES,
        p = probabilities)
    
    particles = particles[new_index, :]
     
    return particles

# %% [markdown]
# Add noise to the particles.

# %%
SIGMA_POS = 2
SIGMA_TURN = np.radians(10)

def add_noise(particles):
    noise  = np.concatenate(
        (
            np.random.normal(0, SIGMA_POS, (NUM_PARTICLES, 1)),
            np.random.normal(0, SIGMA_POS, (NUM_PARTICLES, 1)),
            np.random.normal(0, SIGMA_TURN, (NUM_PARTICLES, 1))
        ), 
        axis=1
    )
    particles += noise
    return particles

# %% [markdown]
# Display robot, particles and best guess.

# %%
def display(map, rx, ry, particles):
    lmap = cv2.cvtColor(map, cv2.COLOR_GRAY2BGR)
    
    # Display particles
    if len(particles) > 0:
        for i in range(NUM_PARTICLES):
            cv2.circle(lmap, 
                       (int(particles[i,0]), int(particles[i,1])), 
                       1, 
                       (255,0,0), 
                       1)
        
    # Display robot
    cv2.circle(lmap, (int(rx), int(ry)), 5, (0,255,0), 10)

    # Display best guess
    if len(particles) > 0:
        px = np.mean(particles[:,0])
        py = np.mean(particles[:,1])
        cv2.circle(lmap, (int(px), int(py)), 5, (0,0,255), 5)

    cv2.imshow('map', lmap)
    video.write(lmap)

# %% [markdown]
# Main routine.

# %%
particles = init()
while True:
    display(map, rx, ry, particles)
    fwd, turn, halt = get_input()
    if halt:
        break
    rx, ry, rtheta = move_robot(rx, ry, rtheta, fwd, turn)
    particles = move_particles(particles, fwd, turn)
    if fwd != 0:
        robot_sensor = sense(rx, ry, noisy=True)        
        weights = compute_weights(particles, robot_sensor)
        particles = resample(particles, weights)
        particles = add_noise(particles)
    cv2.destroyAllWindows()                        

cv2.destroyAllWindows()
# Out:
# 56
# fwd_noisy =  [4.50514807]
# turn_noisy =  [12.18253979]
# 56
# fwd_noisy =  [5.26174637]
# turn_noisy =  [5.24015471]
# 54
# fwd_noisy =  [0.23521969]
# turn_noisy =  [27.26741964]
# 56
# fwd_noisy =  [4.95196087]
# turn_noisy =  [1.67650563]
# 56
# fwd_noisy =  [6.08845985]
# turn_noisy =  [-1.38110839]
# 54
# fwd_noisy =  [0.00385989]
# turn_noisy =  [31.22997312]
# 54
# fwd_noisy =  [0.02313605]
# turn_noisy =  [23.62618621]
# 54
# fwd_noisy =  [-0.43485973]
# turn_noisy =  [48.85248031]
# 56
# fwd_noisy =  [5.74187523]
# turn_noisy =  [24.78247906]
# 54
# fwd_noisy =  [0.12729033]
# turn_noisy =  [24.57846591]
# 56
# fwd_noisy =  [5.03852895]
# turn_noisy =  [-3.05844855]
# 54
# fwd_noisy =  [-0.33263566]
# turn_noisy =  [24.02394263]
# 56
# fwd_noisy =  [5.66578731]
# turn_noisy =  [4.40789778]
# 56
# fwd_noisy =  [5.24095107]
# turn_noisy =  [-5.71479022]
# 56
# fwd_noisy =  [5.4012657]
# turn_noisy =  [2.37025719]
# 56
# fwd_noisy =  [5.2786067]
# turn_noisy =  [10.47943807]
# 54
# fwd_noisy =  [0.22212339]
# turn_noisy =  [23.6459516]
# 56
# fwd_noisy =  [5.69518875]
# turn_noisy =  [8.41240991]
# 56
# fwd_noisy =  [5.07707469]
# turn_noisy =  [-3.78841043]
# 56
# fwd_noisy =  [5.4368556]
# turn_noisy =  [15.4898498]
# 56
# fwd_noisy =  [4.97946308]
# turn_noisy =  [4.50405992]
# 56
# fwd_noisy =  [5.50051062]
# turn_noisy =  [3.17748678]
# 54
# fwd_noisy =  [1.64447962]
# turn_noisy =  [12.98279908]
# 54
# fwd_noisy =  [-0.2506153]
# turn_noisy =  [34.08834638]
# 56
# fwd_noisy =  [5.09081041]
# turn_noisy =  [-9.73539145]
# 56
# fwd_noisy =  [5.44608468]
# turn_noisy =  [4.0281258]
# 56
# fwd_noisy =  [4.17303329]
# turn_noisy =  [14.30872877]
# 56
# fwd_noisy =  [5.30926677]
# turn_noisy =  [13.48451623]
# 56
# fwd_noisy =  [5.89311554]
# turn_noisy =  [-8.99449448]
# 56
# fwd_noisy =  [5.47804845]
# turn_noisy =  [15.79668222]
# 56
# fwd_noisy =  [5.37443962]
# turn_noisy =  [-13.41287594]
# 56
# fwd_noisy =  [4.77818523]
# turn_noisy =  [13.22309189]
# 56
# fwd_noisy =  [5.09062185]
# turn_noisy =  [31.42800348]
# 56
# fwd_noisy =  [4.73387226]
# turn_noisy =  [0.16975577]
# 56
# fwd_noisy =  [4.49080005]
# turn_noisy =  [2.27168407]
# 56
# fwd_noisy =  [4.38291395]
# turn_noisy =  [0.80241309]
# 56
# fwd_noisy =  [4.60886688]
# turn_noisy =  [-1.83877466]
# 56
# fwd_noisy =  [5.74735664]
# turn_noisy =  [-5.84159965]
# 56
# fwd_noisy =  [4.0178812]
# turn_noisy =  [-8.91142809]
# 56
# fwd_noisy =  [4.36006766]
# turn_noisy =  [-1.78635524]
# 56
# fwd_noisy =  [4.81892816]
# turn_noisy =  [-5.50160935]
# 56
# fwd_noisy =  [5.00425533]
# turn_noisy =  [-14.85718822]
# 56
# fwd_noisy =  [4.77930462]
# turn_noisy =  [13.94946781]
# 56
# fwd_noisy =  [4.93855512]
# turn_noisy =  [15.18322611]
# 56
# fwd_noisy =  [4.49176157]
# turn_noisy =  [2.0540475]
# 56
# fwd_noisy =  [4.95558131]
# turn_noisy =  [-5.59285949]
# 56
# fwd_noisy =  [5.20653173]
# turn_noisy =  [4.62174819]
# 56
# fwd_noisy =  [5.52364951]
# turn_noisy =  [-2.00387291]
# 56
# fwd_noisy =  [5.68884346]
# turn_noisy =  [-15.73212916]
# 56
# fwd_noisy =  [5.36263864]
# turn_noisy =  [0.58076769]
# 56
# fwd_noisy =  [5.93851896]
# turn_noisy =  [1.20931183]
# 56
# fwd_noisy =  [4.42474369]
# turn_noisy =  [9.83594199]
# 56
# fwd_noisy =  [5.2731867]
# turn_noisy =  [4.70613765]
# 56
# fwd_noisy =  [5.6290566]
# turn_noisy =  [-28.66505804]
# 56
# fwd_noisy =  [4.8314274]
# turn_noisy =  [-8.47763857]
# 56
# fwd_noisy =  [5.11230777]
# turn_noisy =  [8.89396114]
# 56
# fwd_noisy =  [5.29871492]
# turn_noisy =  [3.53800302]
# 54
# fwd_noisy =  [-0.19186607]
# turn_noisy =  [21.85166094]
# 56
# fwd_noisy =  [5.12808322]
# turn_noisy =  [7.67859529]
# 54
# fwd_noisy =  [0.75754384]
# turn_noisy =  [41.15944561]
# 54
# fwd_noisy =  [-0.03225337]
# turn_noisy =  [30.73723994]
# 56
# fwd_noisy =  [5.38486783]
# turn_noisy =  [-11.15924191]
# 54
# fwd_noisy =  [-0.35727942]
# turn_noisy =  [20.65703738]
# 56
# fwd_noisy =  [4.92480527]
# turn_noisy =  [9.04104391]
# 56
# fwd_noisy =  [5.78021219]
# turn_noisy =  [-11.87457203]
# 56
# fwd_noisy =  [5.80846012]
# turn_noisy =  [-6.71924138]
# 56
# fwd_noisy =  [5.03391372]
# turn_noisy =  [7.08915444]
# 56
# fwd_noisy =  [4.95037326]
# turn_noisy =  [-5.59953741]
# 56
# fwd_noisy =  [5.21744951]
# turn_noisy =  [-3.07810041]
# 56
# fwd_noisy =  [4.27502887]
# turn_noisy =  [7.45606]
# 52
# fwd_noisy =  [-0.5826798]
# turn_noisy =  [-45.02287981]
# 52
# fwd_noisy =  [0.38299126]
# turn_noisy =  [-37.36567714]
# 56
# fwd_noisy =  [5.07393623]
# turn_noisy =  [-18.64950378]
# 56
# fwd_noisy =  [4.19943121]
# turn_noisy =  [6.44060941]
# 52
# fwd_noisy =  [-0.59339541]
# turn_noisy =  [-17.85638138]
# 52
# fwd_noisy =  [0.03030571]
# turn_noisy =  [-23.47264369]
# 56
# fwd_noisy =  [4.61735871]
# turn_noisy =  [-9.31784527]
# 56
# fwd_noisy =  [5.55099249]
# turn_noisy =  [-6.45055054]
# 56
# fwd_noisy =  [5.28752874]
# turn_noisy =  [-8.10551315]
# 56
# fwd_noisy =  [4.21154663]
# turn_noisy =  [4.06371615]
# 56
# fwd_noisy =  [4.3624662]
# turn_noisy =  [7.89648361]
# 56
# fwd_noisy =  [5.27058886]
# turn_noisy =  [-1.96945834]
# 56
# fwd_noisy =  [4.46143225]
# turn_noisy =  [10.68625357]
# 56
# fwd_noisy =  [5.38839525]
# turn_noisy =  [5.28607835]
# 56
# fwd_noisy =  [4.95377538]
# turn_noisy =  [-0.56533117]
# 56
# fwd_noisy =  [4.57686814]
# turn_noisy =  [19.06886221]
# 56
# fwd_noisy =  [4.55396987]
# turn_noisy =  [-1.92956843]
# 52
# fwd_noisy =  [-0.10796073]
# turn_noisy =  [-15.86320029]
# 56
# fwd_noisy =  [4.99285743]
# turn_noisy =  [13.03319962]
# 56
# fwd_noisy =  [5.17441577]
# turn_noisy =  [-6.91902509]
# 54
# fwd_noisy =  [0.08099191]
# turn_noisy =  [27.18515418]
# 56
# fwd_noisy =  [5.47806853]
# turn_noisy =  [-13.02646242]
# 54
# fwd_noisy =  [-0.14536416]
# turn_noisy =  [24.34106698]
# 54
# fwd_noisy =  [0.07319196]
# turn_noisy =  [28.68470828]
# 54
# fwd_noisy =  [0.18953298]
# turn_noisy =  [1.14664645]
# 56
# fwd_noisy =  [4.53260234]
# turn_noisy =  [10.34115398]
# 54
# fwd_noisy =  [-0.27064572]
# turn_noisy =  [31.72435517]
# 54
# fwd_noisy =  [0.27979509]
# turn_noisy =  [29.58971598]
# 54
# fwd_noisy =  [-0.64443432]
# turn_noisy =  [9.85595111]
# 56
# fwd_noisy =  [4.60692394]
# turn_noisy =  [-3.86010978]
# 56
# fwd_noisy =  [4.7003016]
# turn_noisy =  [-16.99180071]
# 56
# fwd_noisy =  [4.44355866]
# turn_noisy =  [2.77067686]
# 56
# fwd_noisy =  [5.53505632]
# turn_noisy =  [-11.68169728]
# 56
# fwd_noisy =  [4.74704011]
# turn_noisy =  [-2.12472225]
# 56
# fwd_noisy =  [4.35709332]
# turn_noisy =  [-16.91408622]
# 56
# fwd_noisy =  [4.74050573]
# turn_noisy =  [-1.03814438]
# 56
# fwd_noisy =  [4.79529975]
# turn_noisy =  [-2.94784433]
# 56
# fwd_noisy =  [5.76548154]
# turn_noisy =  [3.78252992]
# 56
# fwd_noisy =  [5.30443564]
# turn_noisy =  [3.63454546]
# 56
# fwd_noisy =  [4.85834144]
# turn_noisy =  [9.40454036]
# 54
# fwd_noisy =  [-0.13053085]
# turn_noisy =  [25.55375049]
# 54
# fwd_noisy =  [0.23753526]
# turn_noisy =  [30.02091988]
# 54
# fwd_noisy =  [0.07675205]
# turn_noisy =  [15.33415691]
# 54
# fwd_noisy =  [0.67348754]
# turn_noisy =  [6.02435395]
# 56
# fwd_noisy =  [5.13053435]
# turn_noisy =  [-3.04555918]
# 56
# fwd_noisy =  [4.84461674]
# turn_noisy =  [3.32678269]
# 56
# fwd_noisy =  [5.19759813]
# turn_noisy =  [16.18689988]
# 56
# fwd_noisy =  [4.67577428]
# turn_noisy =  [10.42468074]
# 56
# fwd_noisy =  [5.22671533]
# turn_noisy =  [0.58436048]
# 56
# fwd_noisy =  [5.51845814]
# turn_noisy =  [12.18260657]
# 56
# fwd_noisy =  [4.66540194]
# turn_noisy =  [1.42452127]
# 56
# fwd_noisy =  [4.53715092]
# turn_noisy =  [11.50173405]
# 56
# fwd_noisy =  [4.56725016]
# turn_noisy =  [-6.68554315]
# 56
# fwd_noisy =  [4.29081896]
# turn_noisy =  [7.44334648]
# 56
# fwd_noisy =  [5.27242372]
# turn_noisy =  [23.97579426]
# 56
# fwd_noisy =  [5.56782383]
# turn_noisy =  [17.11297349]
# 56
# fwd_noisy =  [4.20394299]
# turn_noisy =  [7.0071482]
# 56
# fwd_noisy =  [5.39237927]
# turn_noisy =  [10.41928318]
# 56
# fwd_noisy =  [4.96379302]
# turn_noisy =  [6.88291486]
# 56
# fwd_noisy =  [5.36544204]
# turn_noisy =  [-11.51803979]
# 56
# fwd_noisy =  [4.4161231]
# turn_noisy =  [10.100602]
# 52
# fwd_noisy =  [-0.3857021]
# turn_noisy =  [-5.30510705]
# 56
# fwd_noisy =  [4.82008108]
# turn_noisy =  [-9.26358836]
# 56
# fwd_noisy =  [5.38135619]
# turn_noisy =  [-1.32102943]
# 52
# fwd_noisy =  [-0.10940873]
# turn_noisy =  [-18.01150061]
# 52
# fwd_noisy =  [0.44376654]
# turn_noisy =  [-14.55120465]
# 52
# fwd_noisy =  [-0.08856884]
# turn_noisy =  [-40.96108479]
# 56
# fwd_noisy =  [5.62403352]
# turn_noisy =  [15.62334177]
# 52
# fwd_noisy =  [-0.07308136]
# turn_noisy =  [-38.26415431]
# 56
# fwd_noisy =  [4.43738474]
# turn_noisy =  [-1.22934419]
# 56
# fwd_noisy =  [4.6599467]
# turn_noisy =  [26.8166693]
# 52
# fwd_noisy =  [-0.63963952]
# turn_noisy =  [-4.3823588]
# 52
# fwd_noisy =  [-1.26770554]
# turn_noisy =  [-24.30614294]
# 52
# fwd_noisy =  [-0.29630716]
# turn_noisy =  [-7.35393617]
# 52
# fwd_noisy =  [-0.29391025]
# turn_noisy =  [-20.2637625]
# 52
# fwd_noisy =  [0.69460517]
# turn_noisy =  [-3.51765206]
# 56
# fwd_noisy =  [4.02186661]
# turn_noisy =  [2.55627554]
# 56
# fwd_noisy =  [5.62289758]
# turn_noisy =  [8.21064985]
# 52
# fwd_noisy =  [-0.15928119]
# turn_noisy =  [-17.80364528]
# 52
# fwd_noisy =  [0.32204009]
# turn_noisy =  [-30.02025937]
# 52
# fwd_noisy =  [0.50562671]
# turn_noisy =  [-28.07227931]
# 52
# fwd_noisy =  [-0.27074339]
# turn_noisy =  [-7.52706844]
# 56
# fwd_noisy =  [5.35589901]
# turn_noisy =  [11.0676711]
# 52
# fwd_noisy =  [0.99465068]
# turn_noisy =  [-32.65132643]
# 56
# fwd_noisy =  [4.98183221]
# turn_noisy =  [7.65109198]
# 52
# fwd_noisy =  [0.0254078]
# turn_noisy =  [-26.84323848]
# 52
# fwd_noisy =  [-0.05607397]
# turn_noisy =  [-9.64544543]
# 56
# fwd_noisy =  [5.1355614]
# turn_noisy =  [-6.7908529]
# 50

# %%
video.release()
