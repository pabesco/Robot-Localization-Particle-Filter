# %%
import numpy as np
import cv2

map = cv2.imread("map.png", 0) # 0 for greyscale, single-channel
HEIGHT, WIDTH = map.shape

print(map)
# Blur map
# map = cv2.GaussianBlur(map, (7,7), 0) # Kernel needs odd dimensions (11,11)

rx, ry, rtheta = (WIDTH/4, HEIGHT/4, 0)

################

STEP = 5
TURN = np.radians(25)

def get_input():
    fwd = 0
    turn = 0
    halt = False
    k = cv2.waitKey(0)
    if k == 56: # Up arrow
        fwd = STEP
    elif k == 54: # Right arrow
        turn = TURN
    elif k == 52: # Left arrow
        turn = -TURN
    else:
        halt = True
    return fwd, turn, halt

################

SIGMA_STEP = 0.5
SIGMA_TURN = np.radians(5) # best way to control trackability for demo

def move_robot(rx, ry, rtheta, fwd, turn):
    # Re-orient and step robot, with noise
    fwd_noisy = fwd + np.random.normal(0.0, SIGMA_STEP, 1)
    rx += fwd_noisy * np.cos(rtheta)
    ry += fwd_noisy * np.sin(rtheta)
    print("fwd_noisy=", fwd_noisy)
    
    turn_noisy = turn + np.random.normal(0.0, SIGMA_TURN, 1)
    rtheta += turn_noisy
    print("turn_noisy=", np.degrees(turn_noisy))

    return rx, ry, rtheta

################

NUM_PARTICLES = 3000

def init():
    particles = np.random.rand(NUM_PARTICLES, 3)
    particles *= np.array( (WIDTH, HEIGHT, np.radians(360)) )
    return particles

#################

def move_particles(particles, fwd, turn):
    particles[:,0] += fwd * np.cos(particles[:,2])
    particles[:,1] += fwd * np.sin(particles[:,2])
    particles[:,2] += turn

    particles[:,0] = np.clip(particles[:,0], 0.0, WIDTH-1)
    particles[:,1] = np.clip(particles[:,1], 0.0, HEIGHT-1)
    return particles

################

def sense(x, y, noisy=False):
    SIGMA_SENSOR = 5
    x = int(x)
    y = int(y)
    if noisy:
        return map[y,x] + np.random.normal(0.0, SIGMA_SENSOR, 1)
    return map[y,x]

###############

def sense(x, y, noisy=False):
    SIGMA_SENSOR = 5
    x = int(x)
    y = int(y)
    if noisy:
        return map[y,x] + np.random.normal(0.0, SIGMA_SENSOR, 1)
    return map[y,x]

###############

def compute_weights(particles, robot_sensor):    
    errors = np.zeros(NUM_PARTICLES)
    for i in range(NUM_PARTICLES):
        particle_sensor = sense(particles[i,0], particles[i,1])
        errors[i] = abs(robot_sensor - particle_sensor)
    weights = np.max(errors) - errors

    # Kill off particles on edge
    weights[
        (particles[:,0] == 0) |
        (particles[:,0] == WIDTH-1) |
        (particles[:,1] == 0) |
        (particles[:,1] == HEIGHT-1)
    ] = 0.0

    # Increase sensitivity
    weights = weights ** 3
    return weights

###############


def resample(particles, weights):
    probabilities = weights / np.sum(weights)
    new_index = np.random.choice(
        NUM_PARTICLES,
        size=NUM_PARTICLES,
        p=probabilities
    )
    particles = particles[new_index,:]
    return particles

############

def add_noise(particles):
    SIGMA_PARTICLE_STEP = 2 #2
    SIGMA_PARTICLE_TURN = np.pi / 24 #np.pi / 24
    noise = np.concatenate((
        np.random.normal(0, SIGMA_PARTICLE_STEP, (NUM_PARTICLES,1)),
        np.random.normal(0, SIGMA_PARTICLE_STEP, (NUM_PARTICLES,1)),
        np.random.normal(0, SIGMA_PARTICLE_TURN, (NUM_PARTICLES,1)),
        ),
        axis=1
    )
    particles += noise
    return particles

############

def display(map, rx, ry, particles):
    lmap = cv2.cvtColor(map, cv2.COLOR_GRAY2BGR)
    
    # Display particles
    if len(particles) > 0 and False:
        for i in range(NUM_PARTICLES):
            cv2.circle(lmap, 
                       (int(particles[i,0]), int(particles[i,1])), 
                       1, 
                       (255,0,0), 
                       1)
        
    # Display robot
    cv2.circle(lmap, (int(rx), int(ry)), 5, (0,255,0), 10)

    # Display best guess
    if len(particles) > 0:
        px = np.mean(particles[:,0])
        py = np.mean(particles[:,1])
        cv2.circle(lmap, (int(px), int(py)), 5, (0,0,255), 5)

    cv2.imshow('map', lmap)

#################

particles = init()
while True:
    display(map, rx, ry, particles)
    fwd, turn, halt = get_input()
    if halt:
        break
    rx, ry, rtheta = move_robot(rx, ry, rtheta, fwd, turn)
    particles = move_particles(particles, fwd, turn)
    if fwd != 0:
        robot_sensor = sense(rx, ry, noisy=True)        
        weights = compute_weights(particles, robot_sensor)
        particles = resample(particles, weights)
        particles = add_noise(particles)
    
cv2.destroyAllWindows()
# Out:
# [[ 79  80  82 ... 133 148 156]
#  [ 78  79  81 ... 138 156 164]
#  [ 76  77  79 ... 147 170 180]
#  ...
#  [181 181 182 ... 174 172 171]
#  [178 178 178 ... 180 179 178]
#  [177 177 177 ... 183 182 182]]
# fwd_noisy= [4.32253744]
# turn_noisy= [-1.24061222]
# fwd_noisy= [5.81376703]
# turn_noisy= [-1.82495722]
# fwd_noisy= [4.96829869]
# turn_noisy= [0.39544992]
# fwd_noisy= [5.81863223]
# turn_noisy= [4.72823533]
# fwd_noisy= [4.79477307]
# turn_noisy= [-2.81963756]
# fwd_noisy= [5.58974905]
# turn_noisy= [5.47134211]
# fwd_noisy= [3.97649716]
# turn_noisy= [-2.33265871]
# fwd_noisy= [0.76390266]
# turn_noisy= [30.06233392]
# fwd_noisy= [0.02836921]
# turn_noisy= [30.82513076]
# fwd_noisy= [-0.10136225]
# turn_noisy= [26.00573922]
# fwd_noisy= [0.2568454]
# turn_noisy= [-34.11559575]
# fwd_noisy= [-0.75448727]
# turn_noisy= [-20.80741594]
# fwd_noisy= [5.34411806]
# turn_noisy= [-3.28358914]
# fwd_noisy= [5.33697939]
# turn_noisy= [-11.91953145]
# fwd_noisy= [4.73773026]
# turn_noisy= [3.53232779]
# fwd_noisy= [4.63159833]
# turn_noisy= [-0.21659285]
# fwd_noisy= [4.88708362]
# turn_noisy= [-3.78175384]
# fwd_noisy= [4.66229742]
# turn_noisy= [-1.09212173]
# fwd_noisy= [5.62784858]
# turn_noisy= [-3.68160821]
# fwd_noisy= [5.58429608]
# turn_noisy= [0.73630246]
# fwd_noisy= [4.85807905]
# turn_noisy= [4.54557587]
# fwd_noisy= [5.26678509]
# turn_noisy= [7.10319793]
# fwd_noisy= [0.3548039]
# turn_noisy= [27.46791804]
# fwd_noisy= [4.74467812]
# turn_noisy= [-3.41591727]
# fwd_noisy= [5.23427301]
# turn_noisy= [-3.25421777]
# fwd_noisy= [4.2501848]
# turn_noisy= [3.46468979]
# fwd_noisy= [5.17558]
# turn_noisy= [-6.85497039]
# fwd_noisy= [4.25410341]
# turn_noisy= [0.42476828]
# fwd_noisy= [-0.30012362]
# turn_noisy= [-17.19577593]
# fwd_noisy= [4.36940323]
# turn_noisy= [2.41614937]
# fwd_noisy= [5.06856587]
# turn_noisy= [-4.96408996]
# fwd_noisy= [-0.37225638]
# turn_noisy= [-28.11215791]
# fwd_noisy= [-0.2313312]
# turn_noisy= [-24.96220312]
# fwd_noisy= [4.98589097]
# turn_noisy= [6.75815082]
# fwd_noisy= [0.48156443]
# turn_noisy= [-32.36361565]
# fwd_noisy= [5.53818773]
# turn_noisy= [2.77869819]
# fwd_noisy= [-0.54483743]
# turn_noisy= [-28.4412228]
# fwd_noisy= [5.07929182]
# turn_noisy= [-6.35313371]
# fwd_noisy= [0.1295144]
# turn_noisy= [-28.22890627]
# fwd_noisy= [4.44572647]
# turn_noisy= [-4.72978525]
# fwd_noisy= [-0.19059041]
# turn_noisy= [-18.88594228]
# fwd_noisy= [1.04453987]
# turn_noisy= [-19.71254493]
# fwd_noisy= [5.01012027]
# turn_noisy= [2.83137682]
# fwd_noisy= [4.58356754]
# turn_noisy= [2.99224418]
# fwd_noisy= [4.33442789]
# turn_noisy= [-1.9221418]
# fwd_noisy= [4.96251487]
# turn_noisy= [-3.56258126]
# fwd_noisy= [4.77060377]
# turn_noisy= [-2.0003131]
# fwd_noisy= [5.13319767]
# turn_noisy= [1.27307322]
# fwd_noisy= [5.38717736]
# turn_noisy= [-3.37619842]
# fwd_noisy= [-0.58903918]
# turn_noisy= [25.84257444]
# fwd_noisy= [5.37290239]
# turn_noisy= [-0.65720674]
# fwd_noisy= [-0.05582689]
# turn_noisy= [25.52584126]
# fwd_noisy= [4.21259427]
# turn_noisy= [6.11856435]
# fwd_noisy= [-1.22789211]
# turn_noisy= [24.07106333]
# fwd_noisy= [4.83457502]
# turn_noisy= [-0.24350072]
# fwd_noisy= [4.5206572]
# turn_noisy= [0.76701611]
# fwd_noisy= [5.58427921]
# turn_noisy= [-2.82889375]
# fwd_noisy= [4.96325082]
# turn_noisy= [-3.6991301]
# fwd_noisy= [5.75572208]
# turn_noisy= [-1.43775638]
# fwd_noisy= [4.98251242]
# turn_noisy= [-2.79672209]
# fwd_noisy= [4.756608]
# turn_noisy= [5.90404857]
# fwd_noisy= [4.13037634]
# turn_noisy= [-7.60748596]
# fwd_noisy= [4.34904355]
# turn_noisy= [3.55263884]
# fwd_noisy= [0.55474054]
# turn_noisy= [-27.09533154]
# fwd_noisy= [-0.04813881]
# turn_noisy= [-25.57490547]
# fwd_noisy= [4.44067883]
# turn_noisy= [1.33447947]
# fwd_noisy= [5.25035421]
# turn_noisy= [-1.27190782]
# fwd_noisy= [0.35085517]
# turn_noisy= [-16.20722641]
# fwd_noisy= [0.19557995]
# turn_noisy= [-19.89355979]
# fwd_noisy= [5.10634757]
# turn_noisy= [-0.10288027]
# fwd_noisy= [-0.44140211]
# turn_noisy= [-23.2154617]
# fwd_noisy= [5.24715191]
# turn_noisy= [1.6656904]
# fwd_noisy= [-0.95329807]
# turn_noisy= [-23.56228298]
# fwd_noisy= [4.6400174]
# turn_noisy= [4.36430627]
# fwd_noisy= [-0.06531324]
# turn_noisy= [-20.21542946]
# fwd_noisy= [4.48054057]
# turn_noisy= [0.6064452]
# fwd_noisy= [0.01459474]
# turn_noisy= [-22.36861664]
# fwd_noisy= [5.22929219]
# turn_noisy= [3.88343076]
# fwd_noisy= [5.20163452]
# turn_noisy= [5.97195375]
# fwd_noisy= [0.79294488]
# turn_noisy= [-24.66757576]
# fwd_noisy= [-1.33737525]
# turn_noisy= [-23.74760904]
# fwd_noisy= [4.82625641]
# turn_noisy= [1.07011662]
# fwd_noisy= [-1.15678772]
# turn_noisy= [-29.91524539]
# fwd_noisy= [5.04501483]
# turn_noisy= [1.35930874]
# fwd_noisy= [-0.48539771]
# turn_noisy= [-24.49870744]
# fwd_noisy= [5.43545588]
# turn_noisy= [5.57868699]
# fwd_noisy= [5.58273657]
# turn_noisy= [0.95809944]
# fwd_noisy= [5.44415745]
# turn_noisy= [4.15326083]
# fwd_noisy= [5.28244792]
# turn_noisy= [5.43300062]
# fwd_noisy= [5.38400266]
# turn_noisy= [-2.31538096]
# fwd_noisy= [5.28455335]
# turn_noisy= [-1.82759978]
# fwd_noisy= [1.01643261]
# turn_noisy= [28.66353581]
# fwd_noisy= [5.53567114]
# turn_noisy= [-2.01582112]
# fwd_noisy= [0.01852892]
# turn_noisy= [28.26233625]
# fwd_noisy= [5.2491938]
# turn_noisy= [-1.8533621]
# fwd_noisy= [4.98431816]
# turn_noisy= [11.23706319]
# fwd_noisy= [4.830868]
# turn_noisy= [-0.20827493]
# fwd_noisy= [-1.39890777]
# turn_noisy= [21.20777512]
# fwd_noisy= [5.84057529]
# turn_noisy= [6.08823583]
# fwd_noisy= [0.20246203]
# turn_noisy= [21.64357237]
# fwd_noisy= [4.26110753]
# turn_noisy= [2.44120369]
# fwd_noisy= [5.63311303]
# turn_noisy= [-11.33008699]
# fwd_noisy= [-0.50376709]
# turn_noisy= [26.64579382]
# fwd_noisy= [0.72567011]
# turn_noisy= [28.81689805]
# fwd_noisy= [4.65707844]
# turn_noisy= [-3.82454077]
# fwd_noisy= [4.98469831]
# turn_noisy= [-0.68935771]
# fwd_noisy= [6.08945873]
# turn_noisy= [2.17400393]
# fwd_noisy= [-0.57898031]
# turn_noisy= [-21.34059769]
# fwd_noisy= [4.68586124]
# turn_noisy= [-0.41614917]
# fwd_noisy= [-0.41776968]
# turn_noisy= [-26.11625849]
# fwd_noisy= [4.73989285]
# turn_noisy= [-5.34941591]
# fwd_noisy= [0.46540037]
# turn_noisy= [-26.87127388]
# fwd_noisy= [4.50125242]
# turn_noisy= [8.84134389]
# fwd_noisy= [5.69726834]
# turn_noisy= [-3.20541244]
# fwd_noisy= [0.20418214]
# turn_noisy= [-22.14135508]
# fwd_noisy= [5.88978461]
# turn_noisy= [-2.91997562]
# fwd_noisy= [0.66302632]
# turn_noisy= [-29.56909295]
# fwd_noisy= [0.05454688]
# turn_noisy= [-25.34934065]
# fwd_noisy= [5.14451311]
# turn_noisy= [-6.92436774]
# fwd_noisy= [0.67825842]
# turn_noisy= [-33.53260479]
# fwd_noisy= [4.94536409]
# turn_noisy= [-5.97425295]
# fwd_noisy= [4.82019826]
# turn_noisy= [5.60117552]
# fwd_noisy= [4.99112656]
# turn_noisy= [-4.82702815]
# fwd_noisy= [4.86443442]
# turn_noisy= [0.66023648]
# fwd_noisy= [5.29376192]
# turn_noisy= [-4.94525199]
# fwd_noisy= [4.88833538]
# turn_noisy= [-5.14440693]
# fwd_noisy= [5.16311363]
# turn_noisy= [2.20144701]
# fwd_noisy= [5.45562457]
# turn_noisy= [-2.42749814]
# fwd_noisy= [5.46903791]
# turn_noisy= [10.00850395]
# fwd_noisy= [4.47760115]
# turn_noisy= [0.73780076]
# fwd_noisy= [5.21209584]
# turn_noisy= [2.56273191]
# fwd_noisy= [5.7862312]
# turn_noisy= [-4.20832331]
# fwd_noisy= [5.58806851]
# turn_noisy= [-0.31514039]
# fwd_noisy= [5.83753521]
# turn_noisy= [-8.39881825]
# fwd_noisy= [0.55664961]
# turn_noisy= [-26.23948903]
# fwd_noisy= [0.36337448]
# turn_noisy= [-23.57104249]
# fwd_noisy= [5.65633188]
# turn_noisy= [3.21543815]
# fwd_noisy= [-0.19457832]
# turn_noisy= [-18.82816119]
# fwd_noisy= [5.35001654]
# turn_noisy= [0.56852738]
# fwd_noisy= [-0.36031197]
# turn_noisy= [-20.33392218]
# fwd_noisy= [4.50275769]
# turn_noisy= [-3.87379183]
# fwd_noisy= [5.99472455]
# turn_noisy= [0.32605117]
# fwd_noisy= [4.79223869]
# turn_noisy= [-0.65412778]
# fwd_noisy= [-0.51063807]
# turn_noisy= [-23.17038144]
# fwd_noisy= [5.10051945]
# turn_noisy= [3.74934653]
# fwd_noisy= [5.65188149]
# turn_noisy= [5.18538937]
# fwd_noisy= [-0.48299311]
# turn_noisy= [-17.43230258]
# fwd_noisy= [4.79503836]
# turn_noisy= [-3.94889897]
# fwd_noisy= [-0.10524946]
# turn_noisy= [-38.12732343]
# fwd_noisy= [5.22811143]
# turn_noisy= [2.49362369]
# fwd_noisy= [0.26234572]
# turn_noisy= [-22.73663339]
# fwd_noisy= [4.5502603]
# turn_noisy= [5.66181165]
# fwd_noisy= [-0.25462714]
# turn_noisy= [-30.73655675]
# fwd_noisy= [4.99741266]
# turn_noisy= [-5.30289149]
# fwd_noisy= [4.97961306]
# turn_noisy= [1.29970925]
# fwd_noisy= [5.25240106]
# turn_noisy= [-8.1550482]
# fwd_noisy= [4.65012328]
# turn_noisy= [1.44895839]
# fwd_noisy= [0.42039082]
# turn_noisy= [26.14568403]
# fwd_noisy= [4.23771811]
# turn_noisy= [-4.77109815]
# fwd_noisy= [0.73620572]
# turn_noisy= [26.74666753]
# fwd_noisy= [5.50389156]
# turn_noisy= [-1.89149168]
# fwd_noisy= [3.95685515]
# turn_noisy= [-0.46562098]
# fwd_noisy= [4.67526618]
# turn_noisy= [-8.81385534]
# fwd_noisy= [4.89629179]
# turn_noisy= [2.95576642]
# fwd_noisy= [4.60169218]
# turn_noisy= [-5.66137416]
# fwd_noisy= [5.72544907]
# turn_noisy= [10.37284753]
# fwd_noisy= [0.17751285]
# turn_noisy= [32.55012312]
# fwd_noisy= [-0.24339307]
# turn_noisy= [15.41009529]
# fwd_noisy= [0.3208946]
# turn_noisy= [18.15017299]
# fwd_noisy= [5.04387743]
# turn_noisy= [-4.78287285]
# fwd_noisy= [0.22362989]
# turn_noisy= [16.94372096]
# fwd_noisy= [0.02002399]
# turn_noisy= [22.5784872]
# fwd_noisy= [5.29629883]
# turn_noisy= [4.72701091]
# fwd_noisy= [4.56178409]
# turn_noisy= [4.23206956]
# fwd_noisy= [4.51159152]
# turn_noisy= [1.51583492]
# fwd_noisy= [4.06810196]
# turn_noisy= [4.08265761]
# fwd_noisy= [4.22101234]
# turn_noisy= [3.19116807]
# fwd_noisy= [5.29771942]
# turn_noisy= [-7.30072303]
# fwd_noisy= [5.68861496]
# turn_noisy= [3.33716831]
# fwd_noisy= [5.67381398]
# turn_noisy= [-2.49739712]
# fwd_noisy= [5.8262358]
# turn_noisy= [1.91064386]
# fwd_noisy= [5.36710015]
# turn_noisy= [2.8271124]
# fwd_noisy= [5.34187365]
# turn_noisy= [-4.13477408]
# fwd_noisy= [4.76656028]
# turn_noisy= [3.9647954]
# fwd_noisy= [6.37409949]
# turn_noisy= [-5.04050946]
# fwd_noisy= [4.56019736]
# turn_noisy= [-2.54026978]
# fwd_noisy= [5.22690448]
# turn_noisy= [-3.76546054]
# fwd_noisy= [4.98341859]
# turn_noisy= [4.04984596]
# fwd_noisy= [4.85304806]
# turn_noisy= [-9.3526113]
# fwd_noisy= [5.03571488]
# turn_noisy= [3.38071938]
# fwd_noisy= [4.62832232]
# turn_noisy= [-7.1393769]
# fwd_noisy= [4.98828793]
# turn_noisy= [0.43909574]
# fwd_noisy= [4.33889202]
# turn_noisy= [-2.47528598]
# fwd_noisy= [-0.24012133]
# turn_noisy= [-21.22816442]
# fwd_noisy= [5.56403381]
# turn_noisy= [0.50879256]
# fwd_noisy= [4.89252338]
# turn_noisy= [-1.26637623]
# fwd_noisy= [-0.51248981]
# turn_noisy= [-23.8327983]
# fwd_noisy= [-0.64430446]
# turn_noisy= [-24.02729932]
# fwd_noisy= [4.70408832]
# turn_noisy= [-5.5361607]
# fwd_noisy= [-0.02894387]
# turn_noisy= [-23.83875283]
# fwd_noisy= [4.79583136]
# turn_noisy= [1.85962612]
# fwd_noisy= [-0.72194734]
# turn_noisy= [-32.87169454]
# fwd_noisy= [4.97161552]
# turn_noisy= [1.95660265]
# fwd_noisy= [-1.19984922]
# turn_noisy= [-32.17774308]
# fwd_noisy= [4.84240236]
# turn_noisy= [1.34747937]
# fwd_noisy= [0.57956819]
# turn_noisy= [-26.83070289]
# fwd_noisy= [4.59119328]
# turn_noisy= [0.22862732]
# fwd_noisy= [-0.50837034]
# turn_noisy= [-24.26633027]
# fwd_noisy= [4.21787282]
# turn_noisy= [6.73968428]
# fwd_noisy= [4.6153645]
# turn_noisy= [1.53489736]
# fwd_noisy= [-0.58108909]
# turn_noisy= [-24.47790666]
# fwd_noisy= [5.65964584]
# turn_noisy= [5.8960241]
# fwd_noisy= [3.80829961]
# turn_noisy= [-2.54340712]
# fwd_noisy= [4.80815626]
# turn_noisy= [1.47813751]
# fwd_noisy= [-0.67507476]
# turn_noisy= [24.04551752]
# fwd_noisy= [5.26756703]
# turn_noisy= [-1.2569895]
# fwd_noisy= [-0.16160538]
# turn_noisy= [25.29828512]
# fwd_noisy= [-1.49523298]
# turn_noisy= [21.74915434]
# fwd_noisy= [3.97759313]
# turn_noisy= [-4.70467737]
# fwd_noisy= [5.47418812]
# turn_noisy= [-2.82121158]
# fwd_noisy= [-0.02658854]
# turn_noisy= [20.01383811]
# fwd_noisy= [0.06420985]
# turn_noisy= [18.39002252]
# fwd_noisy= [-0.00545408]
# turn_noisy= [27.81436102]
# fwd_noisy= [-1.19859935]
# turn_noisy= [17.78613507]
# fwd_noisy= [-0.65966446]
# turn_noisy= [32.19100494]
# fwd_noisy= [0.66619951]
# turn_noisy= [13.05580391]
# fwd_noisy= [0.18496997]
# turn_noisy= [28.96602794]
# fwd_noisy= [-0.25048344]
# turn_noisy= [31.66104428]
# fwd_noisy= [-0.30847887]
# turn_noisy= [27.4683788]
# fwd_noisy= [-0.26393638]
# turn_noisy= [28.09230315]
# fwd_noisy= [0.70621566]
# turn_noisy= [15.13472486]
# fwd_noisy= [4.00064526]
# turn_noisy= [-2.15399027]
# fwd_noisy= [4.7988106]
# turn_noisy= [-5.66629192]
# fwd_noisy= [5.00690937]
# turn_noisy= [-1.31973203]
# fwd_noisy= [-0.96847675]
# turn_noisy= [25.39243541]
# fwd_noisy= [-0.15768414]
# turn_noisy= [29.57416066]
# fwd_noisy= [0.22694568]
# turn_noisy= [27.37106991]
# fwd_noisy= [5.28050584]
# turn_noisy= [7.16064449]
# fwd_noisy= [5.26825118]
# turn_noisy= [-2.54654563]
# fwd_noisy= [5.44135505]
# turn_noisy= [4.53809257]
# fwd_noisy= [4.78928919]
# turn_noisy= [-2.23147534]
# fwd_noisy= [4.67791666]
# turn_noisy= [-0.38235584]
# fwd_noisy= [4.32392098]
# turn_noisy= [4.92481336]
# fwd_noisy= [5.60533213]
# turn_noisy= [0.88515372]
# fwd_noisy= [5.09910674]
# turn_noisy= [-12.91091521]
# fwd_noisy= [4.81542429]
# turn_noisy= [3.82768327]
# fwd_noisy= [5.02773577]
# turn_noisy= [2.2405776]
# fwd_noisy= [4.90992321]
# turn_noisy= [-5.55795058]
# fwd_noisy= [4.30128843]
# turn_noisy= [0.13001655]
# fwd_noisy= [4.24995978]
# turn_noisy= [1.52163896]
# fwd_noisy= [5.36794678]
# turn_noisy= [-3.39646182]
# fwd_noisy= [0.99392866]
# turn_noisy= [15.39824776]
# fwd_noisy= [5.53785952]
# turn_noisy= [0.37618788]
# fwd_noisy= [-0.25501712]
# turn_noisy= [21.63778296]
# fwd_noisy= [0.08339915]
# turn_noisy= [25.48137711]
# fwd_noisy= [4.41258543]
# turn_noisy= [1.94297791]
# fwd_noisy= [6.07509492]
# turn_noisy= [-1.26927047]
# fwd_noisy= [5.75476978]
# turn_noisy= [-2.4837565]
# fwd_noisy= [5.09951042]
# turn_noisy= [-4.96302554]
# fwd_noisy= [4.00203538]
# turn_noisy= [-1.72219253]
# fwd_noisy= [5.12106287]
# turn_noisy= [0.41585474]
# fwd_noisy= [4.89788179]
# turn_noisy= [-7.56557147]
# fwd_noisy= [4.06068016]
# turn_noisy= [0.18652426]
# fwd_noisy= [5.02238072]
# turn_noisy= [7.76513124]
# fwd_noisy= [5.81200954]
# turn_noisy= [-5.09556085]
# fwd_noisy= [4.86387729]
# turn_noisy= [2.42408198]
# fwd_noisy= [4.85636626]
# turn_noisy= [11.02579183]
# fwd_noisy= [5.09239945]
# turn_noisy= [-2.08633734]
# fwd_noisy= [5.1249952]
# turn_noisy= [3.72521781]
# fwd_noisy= [5.59705166]
# turn_noisy= [-1.80771206]
# fwd_noisy= [6.17137591]
# turn_noisy= [6.47804402]
# fwd_noisy= [4.81724352]
# turn_noisy= [-3.29193055]
# fwd_noisy= [4.66576913]
# turn_noisy= [-5.93838706]
# fwd_noisy= [3.90995747]
# turn_noisy= [3.0464131]
# fwd_noisy= [0.38090383]
# turn_noisy= [19.10275271]
# fwd_noisy= [4.51951826]
# turn_noisy= [-6.53068759]
# fwd_noisy= [4.8515475]
# turn_noisy= [9.37750184]
# fwd_noisy= [4.93778681]
# turn_noisy= [-7.01120065]
# fwd_noisy= [0.35695571]
# turn_noisy= [-14.17139967]
# fwd_noisy= [-0.41165591]
# turn_noisy= [-26.85441571]
# fwd_noisy= [4.73093478]
# turn_noisy= [-5.90450673]
# fwd_noisy= [-0.30673796]
# turn_noisy= [-24.67235243]
# fwd_noisy= [0.37476099]
# turn_noisy= [-21.07058953]
# fwd_noisy= [4.31941192]
# turn_noisy= [-3.43544498]
# fwd_noisy= [4.39454205]
# turn_noisy= [-6.78224556]
# fwd_noisy= [4.57692063]
# turn_noisy= [-0.54934068]
# fwd_noisy= [4.4604025]
# turn_noisy= [4.75605659]
# fwd_noisy= [5.4594073]
# turn_noisy= [-3.40369322]
# fwd_noisy= [4.23581483]
# turn_noisy= [-4.78301804]
# fwd_noisy= [-0.14502774]
# turn_noisy= [29.46565427]
# fwd_noisy= [-0.38706899]
# turn_noisy= [25.15701009]
# fwd_noisy= [-0.072757]
# turn_noisy= [21.30125377]
# fwd_noisy= [4.52018406]
# turn_noisy= [0.15664696]
# fwd_noisy= [4.45280431]
# turn_noisy= [-1.16177849]
# fwd_noisy= [5.01465986]
# turn_noisy= [-3.73481284]
